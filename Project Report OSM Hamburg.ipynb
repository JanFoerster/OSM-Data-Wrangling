# %% [markdown]
# <a id="1"></a>
# # OpenStreetMap Data Case Study
# **Name: Jan FOERSTER**
# ***

# %%
# %matplotlib notebook

import pprint

from jfo.schema import schema
from jfo.mySQL3dbConn import mySQLLITE3
from jfo.myXML import Investigation
from jfo.myExtension import myDict2CSVTransformer

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#sample file size 80MB
#xmlfile = 'OpenStreetMap-Hamburg-Sample.osm'

#original file size378MB
xmlfile = 'OpenStreetMap-Hamburg-31.osm'

myOSMfile = Investigation(xmlfile)

# %% [markdown]
# <a id="11"></a>
# ## Map Area
# ***
# This map is of about my hometown and it's direct regional environment, so I’m more interested to see what database querying reveals, and I’d like an opportunity to contribute to its improvement on OpenStreetMap.org by an customized extract from MapZen
#
# - OpenStreet Map: Freie und Hansestadt Hamburg, Germany
#
#
# - __[MapZen Extract](https://mapzen.com/data/metro-extracts/your-extracts/d4104a4aab6c)__

# %%
# %%HTML
# <div class="alert alert-block alert-info">
#     <iframe width="100%" height="100%" frameborder="0" scrolling="no" marginheight="0" marginwidth="0" src="http://www.openstreetmap.org/export/embed.html?bbox=9.534759521484375%2C53.38291881008687%2C10.441131591796877%2C53.7438381234801&amp;layer=mapnik&amp;marker=53.56371244239144%2C9.987602233886719" style="border: 1px solid black"></iframe>
#     <br/>
#     <small>
#         <a href="http://www.openstreetmap.org/?mlat=53.5637&amp;mlon=9.9876#map=11/53.5637/9.9876">Show Detailed Map</a>
#     </small>
# </div>
# Out:
# <div class="alert alert-block alert-info">
#     <iframe width="100%" height="100%" frameborder="0" scrolling="no" marginheight="0" marginwidth="0" src="http://www.openstreetmap.org/export/embed.html?bbox=9.534759521484375%2C53.38291881008687%2C10.441131591796877%2C53.7438381234801&amp;layer=mapnik&amp;marker=53.56371244239144%2C9.987602233886719" style="border: 1px solid black"></iframe>
#     <br/>
#     <small>
#         <a href="http://www.openstreetmap.org/?mlat=53.5637&amp;mlon=9.9876#map=11/53.5637/9.9876">Show Detailed Map</a>
#     </small>
# </div>

# %% [markdown]
# <a id="11"></a>
# ## Data Infrastructure
# ***
# With the method *'count_tags()'* of my class *'Investigation'*, I save the number of unique tags of chosen XML-file within a private dictionary. By applying the method *'get_Tags()'*, I receive the full information.

# %% [markdown]
# ### Unique Tags

# %%
myOSMfile.count_Tags()
pprint.pprint(myOSMfile.get_Tags())
# Out:
# {'bounds': 1,
#  'member': 84855,
#  'nd': 2118748,
#  'node': 1609887,
#  'osm': 1,
#  'relation': 6524,
#  'tag': 1574672,
#  'way': 300719}

# %% [markdown]
# In order to understand, which attributes are used by which XML-tag the method *'view_Tags_Attributes'* saves this in a further private dictionary.

# %%
myOSMfile.view_Tags_Attributes()
pprint.pprint(myOSMfile.get_Tags_Attributes())
# Out:
# defaultdict(<type 'set'>, {'node': set(['changeset', 'uid', 'timestamp', 'lon', 'version', 'user', 'lat', 'id']), 'nd': set(['ref']), 'bounds': set(['minlat', 'maxlon', 'minlon', 'maxlat']), 'member': set(['role', 'ref', 'type']), 'tag': set(['k', 'v']), 'relation': set(['changeset', 'uid', 'timestamp', 'version', 'user', 'id']), 'way': set(['changeset', 'uid', 'timestamp', 'version', 'user', 'id']), 'osm': set(['timestamp', 'version', 'generator'])})

# %% [markdown]
# ### Patterns in the Tags

# %% [markdown]
# The 'k' attribute of tag 'tag' contains different patterns. In order to identify potential bias from used characters, all content has been classidied as following by the method *'audit_Data_Chars'*:
#
# * lower : regex pattern is valid, if tags contain only lowercase letters
# * lower_colon: regex pattern is valid, if tags contain only colons
# * problemchars: regex pattern is valid, if tags contain characters, which could cause issue, e.g. '=\+/&<>;\'"\?%#$@\,\. \t\r\n'
# * other: regex pattern is valid, if tags contain only nothing from above

# %%
myOSMfile.audit_Data_Chars()
pprint.pprint(myOSMfile.get_Problematic_Chars())
# Out:
# {'lower': 789084, 'lower_colon': 736073, 'other': 49515, 'problemchars': 0}

# %% [markdown]
# ### Users, who have contributed to OSM
# The 'user' attribute of tag 'node' reveals information, which user have contributed most / least to OSM for nodes. The method *'audit_Unique_Values('node', 'user')'*.

# %%
myOSMfile.audit_Unique_Values('node', 'user')
pprint.pprint(myOSMfile.sort_Dictionary(myOSMfile.get_Unique_Values())[:10])
# Out:
# [('fahrrad', 121258),
#  ('svbr', 116237),
#  ('Abendstund', 93915),
#  ('sundew', 86310),
#  ('Divjo', 74068),
#  ('findichgut', 64352),
#  (u'gl\xfchw\xfcrmchen', 60367),
#  ('vademecum', 51521),
#  ('Joke123', 45668),
#  ('simlox', 44720)]

# %% [markdown]
# The 'user' attribute of tag 'way' reveals information, which user have contributed most / least to OSM for ways. The method *'audit_Unique_Values('node', 'user')'*.

# %%
myOSMfile.audit_Unique_Values('way', 'user')
pprint.pprint(myOSMfile.sort_Dictionary(myOSMfile.get_Unique_Values())[:10])
# Out:
# [('fahrrad', 144620),
#  ('svbr', 137218),
#  ('Abendstund', 109168),
#  ('sundew', 95625),
#  ('Divjo', 90719),
#  ('findichgut', 75579),
#  (u'gl\xfchw\xfcrmchen', 66099),
#  ('vademecum', 60115),
#  ('Joke123', 53585),
#  ('simlox', 50068)]

# %% [markdown]
# The Top10 of contributers are:
#     * 'fahrrad'
#     * 'svbr'
#     * 'Abendstund'
#     * 'sundew'
#     * 'Divjo'
#     * 'findichgut'
#     * 'glühwürmchen'
#     * 'vademecum'
#     * 'Joke123'
#     * 'simlox'

# %% [markdown]
# <a id="12"></a>
# ## Problems Encountered in the Map
# ***
# The sample file has been  loaded, parsed, analyzed, cleaned - if necessary - and saved in SQLite3 database.

# %% [markdown]
# <a id="121"></a>
# ### Phone Numbers
# ***
# The major problem has been to have phone numbers written in a standardized format, e.g. "+49 (0)40 XXXXXXX", as some persons have indicated international prefix and some persons not. In case international prefix has been added, there hasn't been a constant formatting way for further notion.

# %%
myOSMfile.audit_Phone_Numbers()
pprint.pprint(myOSMfile.get_Aligned_Phone_Numbers())
# Out:
# defaultdict(<type 'set'>, {'+494028787174': '+49 (0)40 28787174', '+494028806718': '+49 (0)40 28806718', '+494059355340': '+49 (0)40 59355340', '04054880575': '+49 (0)40 54880575', '+494065067790': '+49 (0)40 65067790', '04036005520': '+49 (0)40 36005520', '+494079027754': '+49 (0)40 79027754', '+49404142760': '+49 (0)40 4142760', '+4940545077': '+49 (0)40 545077', '+494078808114': '+49 (0)40 78808114', '+49406415933': '+49 (0)40 6415933', '+4940428832225': '+49 (0)40 428832225', '+494032027757': '+49 (0)40 32027757', '+494088175508': '+49 (0)40 88175508', '+49407941630': '+49 (0)40 7941630', '+4940366560': '+49 (0)40 366560', '+4940776374': '+49 (0)40 776374', '+494058915971': '+49 (0)40 58915971', '+49402514524': '+49 (0)40 2514524', '+49408317422': '+49 (0)40 8317422', '+494039805790': '+49 (0)40 39805790', '0406523906': '+49 (0)40 6523906', '+4940853510': '+49 (0)40 853510', '+494032031387': '+49 (0)40 32031387', '+494076795391': '+49 (0)40 76795391', '+49403344113340': '+49 (0)40 334411334 0', '+4940255674': '+49 (0)40 255674', '+49402841910': '+49 (0)40 2841910', '+4940883070030': '+49 (0)40 883070030', '+494023934489': '+49 (0)40 23934489', '0404399116': '+49 (0)4+ 49 (0)439 9116', '+4940303850': '+49 (0)40 303850', '+49408320171': '+49 (0)40 8320171', '+4940428382297': '+49 (0)40 428382297', '0049+4042816255': '+49 (0)+4 042816255', '004904065040500': '+49 (0)40 65040500', '+494045013169': '+49 (0)40 45013169', '+4904084050626': '+49 (0)40 84050626', '+404043095451': '+404043095451', '+4940473420': '+49 (0)40 473420', '+494063733172': '+49 (0)40 63733172', '+494046635388': '+49 (0)40 46635388', '+4940702020': '+49 (0)40 702020', '+494074212500': '+49 (0)40 74212500', '+494065990532': '+49 (0)40 65990532', '+494059467844': '+49 (0)40 59467844', '04044191821': '+49 (0)4+ 49 (0)441 91821', '+494030085532': '+49 (0)40 30085532', '+494060862209': '+49 (0)40 60862209', '+494042108581': '+49 (0)40 42108581', '+494020982089': '+49 (0)40 20982089', '+4941033208': '+49 (0)41 033208', '+4941018303486': '+49 (0)41 018303486', '+4940741054115': '+49 (0)40 741054115', '+4940212447': '+49 (0)40 212447', '04038992070': '+49 (0)40 38992070', '+49402296664': '+49 (0)40 2296664', '+494061193643': '+49 (0)40 61193643', '+4940225630': '+49 (0)40 225630', '+4940205037': '+49 (0)40 205037', '+494038904892': '+49 (0)40 38904892', '+494076793389': '+49 (0)40 76793389', '+494030202460': '+49 (0)40 30202460', '+494021008706': '+49 (0)40 21008706', '+494032527645': '+49 (0)40 32527645', '+490463311489': '+49 (0)46 3311489', '+4940610134': '+49 (0)40 610134', '+4940226161511': '+49 (0)40 226161511', '+49410148535': '+49 (0)41 0148535', '+494030039392': '+49 (0)40 30039392', '+494039990043': '+49 (0)40 39990043', '+49402204908': '+49 (0)40 2204908', '+49040431720': '+49 (0)40 431720', '+494074212340': '+49 (0)40 74212340', '+49404221597': '+49 (0)40 4221597', '+4940272659': '+49 (0)40 272659', '04083210951': '+49 (0)40 83210951', '+494050773607': '+49 (0)40 50773607', '+49402368216': '+49 (0)40 2368216', '+494038087690': '+49 (0)40 38087690', '+494020982833': '+49 (0)40 20982833', '+4940777434': '+49 (0)40 777434', '+49404209095': '+49 (0)40 4209095', '04089980': '+49 (0)40 89980', '0406413124': '+49 (0)40 6413124', '+49404102920': '+49 (0)40 4102920', '0407521819': '+49 (0)40 7521819', '+49402501860': '+49 (0)40 2501860', '+4940228060': '+49 (0)40 228060', '+49913181159595': '+49 (0)91 318115959 5', '+4940537998510': '+49 (0)40 537998510', '+4940418935': '+49 (0)40 418935', '+4940562839': '+49 (0)40 562839', '+494076972434': '+49 (0)40 76972434', '+494054007509': '+49 (0)40 54007509', '+494076758920': '+49 (0)40 76758920', '+49410387302': '+49 (0)41 0387302', '+494041498310': '+49 (0)40 41498310', '+494028058260': '+49 (0)40 28058260', '+494078807709': '+49 (0)40 78807709', '+49402299055': '+49 (0)40 2299055', '+4940213711': '+49 (0)40 213711', '+49402202753': '+49 (0)40 2202753', '+494041125580': '+49 (0)40 41125580', '+49410147610': '+49 (0)41 0 ...

# %% [markdown]
# <a id="122"></a>
# ### Postal Codes
# ***
# All postal codes have been indicated correctly. No cleaning has been required.

# %%
myOSMfile.audit_Zip_Codes()
pprint.pprint(myOSMfile.get_ZIP_Codes())
# Out:
# defaultdict(<type 'set'>, {'21647': '21647', '22175': '22175', '22177': '22177', '25462': '25462', '22179': '22179', '25469': '25469', '22589': '22589', '22587': '22587', '22761': '22761', '22763': '22763', '22765': '22765', '20457': '20457', '22769': '22769', '21079': '21079', '21075': '21075', '21077': '21077', '21073': '21073', '21107': '21107', '21109': '21109', '20357': '20357', '21218': '21218', '20355': '20355', '20354': '20354', '22391': '22391', '20359': '20359', '22081': '22081', '22083': '22083', '22085': '22085', '22087': '22087', '22089': '22089', '20537': '20537', '20535': '20535', '22459': '22459', '22559': '22559', '20539': '20539', '21614': '21614', '22869': '22869', '22549': '22549', '21129': '21129', '22547': '22547', '25421': '25421', '22609': '22609', '22303': '22303', '22301': '22301', '22307': '22307', '22305': '22305', '22309': '22309', '21220': '21220', '21224': '21224', '21037': '21037', '20095': '20095', '22047': '22047', '22041': '22041', '22043': '22043', '22049': '22049', '21635': '21635', '20249': '20249', '22339': '22339', '22337': '22337', '22880': '22880', '22335': '22335', '20099': '20099', '22113': '22113', '22111': '22111', '22607': '22607', '22605': '22605', '21629': '21629', '22119': '22119', '20097': '20097', '21149': '21149', '22299': '22299', '22529': '22529', '22527': '22527', '21147': '21147', '22297': '22297', '22523': '22523', '22525': '22525', '20253': '20253', '20251': '20251', '20257': '20257', '20255': '20255', '21217': '21217', '20459': '20459', '22453': '22453', '20146': '20146', '22457': '22457', '20144': '20144', '22455': '22455', '20148': '20148', '20149': '20149', '20259': '20259', '22767': '22767', '25488': '25488', '25482': '25482'})

# %% [markdown]
#  <a id="123"></a>
# ### Street Names
# ***
# All street names have been indicated correctly with only three exceptions, which have been corrected, whereas numbers have been inidcated in combination with street names. These three house numbers have been deleted.

# %%
myOSMfile.audit_Street_Names()
#pprint.pprint(myOSMfile.sort_Dictionary(myOSMfile.get_Street_Names()))
#pprint.pprint(myOSMfile.get_Street_Names())
#pprint.pprint('Unknown Streets %s' % + myOSMfile.get_Street_Names('unknown'))
#pprint.pprint('Unknown Streets %s' % + myOSMfile.get_Street_Names('mysterious'))
sorted(myOSMfile.get_Aligned_Street_Names().keys())
# Out:
# [u'ABC-Stra\xdfe',
#  'Aastwiete',
#  u'Abbestra\xdfe',
#  'Abendrothsweg',
#  u'Abteistra\xdfe',
#  u'Abtstra\xdfe',
#  u'Achter L\xfcttmoor',
#  'Achter de Hoef',
#  u'Achter de H\xf6f',
#  'Achter de Weiden',
#  'Achterkamp',
#  'Achtern Barls',
#  'Achtern Born',
#  'Achtern Brack',
#  'Achtern Kronskamp',
#  'Achtern Moor',
#  'Achtern Sand',
#  'Achtern Styg',
#  'Achterndiek',
#  u'Ackermannstra\xdfe',
#  'Ackerstieg',
#  u'Adalbert-Stifter-Stra\xdfe',
#  u'Adalbertstra\xdfe',
#  'Adebarweg',
#  'Adenauerallee',
#  u'Adickesstra\xdfe',
#  'Adlerhorst',
#  u'Adlerstra\xdfe',
#  u'Admiralit\xe4tstra\xdfe',
#  u'Adolf-Wagner-Stra\xdfe',
#  'Adolf-von-Elm-Hof',
#  u'Adolph-Sch\xf6nfelder-Stra\xdfe',
#  u'Adolphsbr\xfccke',
#  'Adolphsplatz',
#  u'Afrikastra\xdfe',
#  'Agathe-Lasch-Weg',
#  u'Agathenstra\xdfe',
#  u'Agnesstra\xdfe',
#  'Ahornallee',
#  'Ahornkamp',
#  u'Ahornstra\xdfe',
#  'Ahornweg',
#  'Akazienallee',
#  'Akazienweg',
#  'Akeleiweg',
#  u'Alardusstra\xdfe',
#  'Alberichstieg',
#  u'Albers-Sch\xf6nberg-Stieg',
#  u'Albers-Sch\xf6nberg-Weg',
#  'Albershof',
#  'Albert-Einstein-Ring',
#  u'Albert-Sch\xe4fer-Weg',
#  u'Albertine-Assor-Stra\xdfe',
#  'Albertiweg',
#  u'Albertstra\xdfe',
#  u'Albrechtstra\xdfe',
#  'Aldenrathsweg',
#  u'Alexander-Zinn-Stra\xdfe',
#  u'Alexanderstra\xdfe',
#  'Alfred-Beit-Weg',
#  u'Alfred-Johann-Levy-Stra\xdfe',
#  'Alfred-Wegener-Weg',
#  u'Alfredstra\xdfe',
#  u'Algermissenstra\xdfe',
#  'Alkmenenring',
#  'Allende-Platz',
#  u'Allensteiner Stra\xdfe',
#  u'Allersstra\xdfe',
#  'Alpenrosenweg',
#  'Alsenplatz',
#  u'Alsenstra\xdfe',
#  'Alsterarkaden',
#  'Alsterberg',
#  'Alsterchaussee',
#  'Alsterdorfer Damm',
#  'Alsterdorfer Markt',
#  u'Alsterdorfer Stra\xdfe',
#  'Alsterglacis',
#  'Alsterkamp',
#  'Alsterkrugchaussee',
#  u'Alsterkr\xfcger Kehre',
#  'Alsterterrasse',
#  'Alstertor',
#  'Alstertwiete',
#  'Alsterufer',
#  'Alte Aue',
#  u'Alte Bahnhofstra\xdfe',
#  u'Alte Elbgaustra\xdfe',
#  'Alte Franzosenheide',
#  u'Alte Kollaustra\xdfe',
#  u'Alte K\xf6nigstra\xdfe',
#  u'Alte Landstra\xdfe',
#  'Alte Marsch',
#  u'Alte Rabenstra\xdfe',
#  'Alte Schleuse',
#  u'Alte S\xfclldorfer Landstra\xdfe',
#  u'Alte Volksparkstra\xdfe',
#  u'Alte W\xf6hr',
#  'Alten Weden',
#  'Altenfelder Weg',
#  'Altenwerder Damm',
#  'Altenwerder Hauptdeich',
#  u'Altenwerder Hauptstra\xdfe',
#  'Alter Damm',
#  'Alter Elbdeich',
#  'Alter Fischmarkt',
#  u'Alter F\xe4hrweg',
#  u'Alter G\xfcterbahnhof',
#  'Alter Kirchdeich',
#  u'Alter L\xf6schplatz',
#  'Alter Postweg',
#  'Alter Steinweg',
#  'Alter Teichweg',
#  'Alter Wall',
#  'Alter Wandrahm',
#  'Alter Weg',
#  u'Altklosterbergstra\xdfe',
#  u'Altl\xe4nder Stra\xdfe',
#  'Altonaer Chaussee',
#  u'Altonaer Poststra\xdfe',
#  u'Altonaer Stra\xdfe',
#  u'Altst\xe4dter Stra\xdfe',
#  u'Altst\xe4dter Twiete',
#  u'Altwiedenthaler H\xf6he',
#  u'Altwiedenthaler Stra\xdfe',
#  'Altwiedenthaler Twiete',
#  u'Aluminiumstra\xdfe',
#  'Alvesener Schulweg',
#  'Alwin-Lippert-Weg',
#  'Am Abhang',
#  'Am Alten Estesperrwerk',
#  'Am Alten Gericht',
#  'Am Alten Posthaus',
#  'Am Alten Schlachthof',
#  'Am Altenwerder Kirchtal',
#  'Am Anger',
#  'Am Aschenland',
#  'Am Bach',
#  'Am Bahndamm',
#  'Am Bahnhof',
#  'Am Ballinkai',
#  'Am Barls',
#  'Am Baumwall',
#  'Am Beedenkamp',
#  'Am Beerenwald',
#  u'Am Birkenw\xe4ldchen',
#  'Am Blumenacker',
#  u'Am Bl\xf6cken',
#  'Am Borg',
#  'Am Born',
#  'Am Botterbarg',
#  'Am Brabandkanal',
#  'Am Brack',
#  'Am Bramfelder Zoll',
#  'Am Brook',
#  'Am Brunnenhof',
#  u'Am Br\xfcnschendiek',
#  'Am Bundesbahnhof',
#  'Am Burgberg',
#  'Am Centrumshaus',
#  'Am Dalmannkai',
#  'Am Diebsteich',
#  'Am Diggen',
#  'Am Dulsbergbad',
#  'Am Ehrenmal',
#  'Am Eichenplatz',
#  'Am Eichholz',
#  'Am Eiland',
#  'Am Eisenwerk',
#  'Am Elbdeich',
#  'Am Elbtunnel',
#  u'Am Elisabethgeh\xf6lz',
#  'Am Estedeich',
#  'Am Exerzierplatz',
#  'Am Feenteich',
#  'Am Felde',
#  'Am Festungsgraben',
#  'Am Frankenberg',
#  'Am Franzosenhut',
#  'Am Freibad',
#  'Am Fuchsberg',
#  u'Am F\xe4hrkanal',
#  'Am Geesttor',
#  'Am Gehegegraben',
#  'Am Genter Ufer',
#  'Am Gleise',
#  'Am Gojenboom',
#  'Am Grasweg',
#  u'Am Gro\xdfen Dahlen',
#  'Am Hafen',
#  'Am Hang',
#  'Am Hasenberge',
#  'Am Heidebad',
#  'Am Heidhagen',
#  'Am Heisterkamp',
#  'Am Hexenberg',
#  'Am Hirschpark',
#  u'Am Hohen Kn\xe4bel',
#  'Am Hollen',
#  'Am Husarendenkmal',
#  u'Am H\xfcnenstein',
#  u'Am H\xfc\xdfelhus',
#  'Am Inselpark',
#  'Am Internationalen Seegerichtshof',
#  'Am Irrgarten',
#  'Am Isfeld',
#  'Am Jachthafen',
#  'Am Johannisland',
#  u'Am J\xe4gerholz',
#  'Am Kaiserkai',
#  'Am Kamp',
#  'Am Katzenberg',
#  'Am Kiekeberg',
#  'Am Kiesberg',
#  u'Am Kla\u0308rwerk',
#  'Am Klein Flottbeker Bahnhof',
#  'Am Kleinen Dahlen',
#  'Am Kleinen Kanal',
#  'Am Kleinen Teich',
#  'Am Klingenberg',
#  u'Am Kl\xe4rwerk',
#  u'Am Kl\xf6vensteen',
#  'Am Kratt',
#  'Am Kriegerdenkmal',
#  u'Am Kr\xe4henberg',
#  u'Am Kr\xf6nrey',
#  'Am Kuchenberg',
#  'Am Landpflegeheim',
#  'Am Langdiek',
#  'Am Langenborn',
#  'Am Langenzug',
#  'Am Leuchtturm',
#  'Am Licentiatenberg',
#  'Am Lohhof',
#  u'Am Lohm\xfchlenpark',
#  'Am Lustberg',
#  u'Am L\xfcdemannschen Park',
#  'Am Mariendom',
#  'Am Marienhof',
#  'Am Markt',
#  'Am Marktplatz',
#  u'Am Martensgeh\xf6lz',
#  u'Am Moorg\xfcrtel',
#  u'Am M\xfchlenberg',
#  'Am Neugrabener Bahnhof',
#  u'Am Neul\xe4nder Baggerteich',
#  u'Am Neul\xe4nder Gewerbepark',
#  'Am Neumarkt',
#  'Am Nobisteich',
#  'Am Oortensiek',
#  'Am Osdorfer Born',
#  'Am Papenbrack',
#  'Am Pavillon',
#  'Am Pflug',
#  'Am Plack',
#  'Am Pumpenkamp',
#  'Am Quickborn',
#  'Am Radeland',
#  'Am Rathenaupark',
#  'Am Redder',
#  'Am Ree',
#  'Am Reiherhorst',
#  'Am Riesenkamp',
#  'Am Rissener Bahnhof',
#  'Am Rotberg',
#  'Am Rugen End',
#  u'Am R\xf6hricht',
#  u'Am R\xfctersberg',
#  'Am Saal',
#  'Am Sandberg',
#  'Am Sandtorkai',
#  'Am Sandtorpark',
#  'Am Scheinberg',
#  'Am Schulsteig',
#  'Am Schulteich',
#  'Am Schwarzenberg-Campus',
#  u'Am Sch\xfctzenplatz',
#  'Am See',
#  'Am Soldatenfriedhof',
#  'Am Sood',
#  'Am Soodhof',
#  'Am Sorgfeld',
#  u'Am Spr\xfctzmoorgraben',
#  'Am Stadtforst',
#  'Am Stadtgraben',
#  'Am Staubecken',
#  'Am Steinlager',
#  'Am Storchennest',
#  'Am Strandkai',
#  'Am Sumpfgraben',
#  'Am Tie',
#  'Am Torbogen',
#  'Am Turnplatz',
#  'Am Veringhof',
#  'Am Viverdamm',
#  'Am Vulkanhafen',
#  'Am Waldpark',
#  u'Am Waldschl\xf6\xdfchen',
#  'Am Wall',
#  'Am Wasserberg',
#  'Am Weidengrund',
#  'Am Weiher',
#  'Am Weinberg',
#  u'Am Wei\xdfenberge',
#  'Am Werder',
#  'Am Wesselhoeftpark',
#  'Am Westerpark',
#  'Am Windhukkai',
#  'Am Ziegelteich',
#  'Am Zollhafen',
#  u'Am \xdcberwinterungshafen',
#  'Amalie-Dietrich-Stieg',
#  'Amalie-Schoppe-Weg',
#  u'Amalienstra\xdfe',
#  u'Amandastra\xdfe',
#  u'Amandus-Stubbe-Stra\xdfe',
#  'Ameisenkamp',
#  u'Amelungstra\xdfe',
#  'Ammernweg',
#  'Amselstieg',
#  u'Amselstra\xdfe',
#  'Amselweg',
#  u'Amsinckstra\xdfe',
#  u'Amundsenstra\xdfe',
#  u'Am\xe1lia-Rodrigues-Weg',
#  'An de Geest',
#  'An den Fuhren',
#  'An den Geestbergen',
#  u'An den H\xf6fen',
#  'An den Wiesen',
#  'An den Ziegelteichen',
#  'An der Alster',
#  'An der Bahn',
#  u'An der Bl\xfctenmauer',
#  'An der Doppeleiche',
#  'An der Eiche',
#  'An der Falkenbek',
#  'An der Feldmark',
#  'An der Fischbek',
#  'An der Flottbek',
#  'An der Hafenbahn',
#  'An der Hasenkuhle',
#  'An der Horeburg',
#  'An der Landscheide',
#  'An der Lohbek',
#  'An der Lohe',
#  'An der Marienanlage',
#  u'An der M\xfchlenau',
#  u'An der M\xfchlenwettern',
#  'An der Rennbahn',
#  'An der Rennkoppel',
#  u'An der Stadthausbr\xfccke',
#  'An der Strecke',
#  'An der Tonkuhle',
#  'An der Verbindungsbahn',
#  u'An der Windm\xfchle',
#  'Anberg',
#  'Anckelmannsplatz',
#  u'Anckelmannstra\xdfe',
#  'Anderheitsallee',
#  u'Andersenstra\xdfe',
#  u'Andersenstra\ufffde',
#  'Andreas-Knack-Ring',
#  u'Andreas-Meyer-Stra\xdfe',
#  u'Andreasstra\xdfe',
#  'Aneken',
#  u'Angelnstra\xdfe',
#  u'Angerstra\xdfe',
#  'Anna-Hollmann-Weg',
#  u'Anna-L\xfchring-Weg',
#  u'Anne-Frank-Stra\xdfe',
#  'Anne-Frank-Weg',
#  u'Annenstra\xdfe',
#  'Ansgariusweg',
#  'Ansgarweg',
#  u'Ansorgestra\xdfe',
#  'Antilopenstieg',
#  u'Anton-R\xe9e-Weg',
#  u'Antonistra\xdfe',
#  u'Antwerpenstra\xdfe',
#  u'Anzengruberstra\xdfe',
#  u'Apenrader Stra\xdfe',
#  'Appelboomtwiete',
#  u'Appelb\xfctteler Weg',
#  'Appelhoff',
#  'Appener Weg',
#  'Appenstedter Weg',
#  u'Appuhnstra\xdfe',
#  'Ardestorfer Weg',
#  'Arensweg',
#  u'Armbruststra\xdfe',
#  u'Armgartstra\xdfe',
#  u'Arminiusstra\xdfe',
#  'Armwischenweg',
#  u'Arndtstra\xdfe',
#  u'Arnemannstra\xdfe',
#  'Arnemannweg',
#  u'Arnimstra\xdfe',
#  u'Arnisstra\xdfe',
#  u'Arnkielstra\xdfe',
#  'Arno-Schmidt-Platz',
#  u'Arnold-Heise-Stra\xdfe',
#  u'Arnoldstra\xdfe',
#  'Aronstabweg',
#  'Arp-Schnitger-Stieg',
#  u'Asbeckstra\xdfe',
#  'Asmusweg',
#  'Assorweg',
#  u'Asternstra\xdfe',
#  'Asternweg',
#  'Astweg',
#  'Aue-Hauptdeich',
#  'Auedeich',
#  u'Auenstra\xdfe',
#  u'Auerbachstra\xdfe',
#  'Auesiel',
#  'Auf dem Acker',
#  'Auf dem Berge',
#  'Auf dem Damm',
#  'Auf dem Kamp',
#  u'Auf dem Kn\xfcll',
#  'Auf dem Kollauer Hof',
#  u'Auf dem K\xf6nigslande',
#  'Auf dem Salzstock',
#  'Auf dem Sande',
#  'Auf dem Wittenberg',
#  'Auf den Bengen',
#  u'Auf den Bl\xf6cken',
#  'Auf der Brandshofer Schleuse',
#  'Auf der Hohen Schaar',
#  u'Auf der H\xf6he',
#  u'Auf der Jahnh\xf6he',
#  'Auf der Koppel',
#  'Auf der Lohe',
#  'August-Bolten-Weg',
#  u'August-Kirch-Stra\xdfe',
#  'August-Schlicka-Weg',
#  'August-Somann-Weg',
#  u'Auguste-Baur-Stra\xdfe',
#  u'Augustenburger Stra\xdfe',
#  'Augustenburger Ufer',
#  'Augustenpassage',
#  u'Augustinstra\xdfe',
#  u'Auguststra\xdfe',
#  'Aurikelstieg',
#  u'Ausschl\xe4ger Allee',
#  u'Ausschl\xe4ger Billdeich',
#  u'Ausschl\xe4ger Elbdeich',
#  u'Ausschl\xe4ger Weg',
#  u'Australiastra\xdfe',
#  u'Austra\xdfe',
#  'Autal',
#  'Auweide',
#  u'Au\xdfenm\xfchlendamm',
#  u'Au\xdfenm\xfchlenweg',
#  u'Avenariusstra\xdfe',
#  u'Averhoffstra\xdfe',
#  'Axel-Springer-Platz',
#  u'Baakenh\xf6ft',
#  'Baarkamp',
#  'Baben Brandheid',
#  'Babenbrook',
#  u'Babendiekstra\xdfe',
#  'Babenwischenweg',
#  'Bachstelzenweg',
#  u'Bachstra\xdfe',
#  'Bachtwiete',
#  u'Badestra\xdfe',
#  u'Baererstra\xdfe',
#  u'Bahng\xe4rten',
#  u'Bahnhofstra\xdfe',
#  u'Bahnstra\xdfe',
#  'Bahrenfelder Chaussee',
#  'Bahrenfelder Kirchenweg',
#  'Bahrenfelder Marktplatz',
#  'Bahrenfelder Steindamm',
#  u'Bahrenfelder Stra\xdfe',
#  'Bahrenfelderstr',
#  u'Bahrstra\xdfe',
#  u'Balduinstra\xdfe',
#  'Ballerstaedtweg',
#  'Ballindamm',
#  'Balthasarweg',
#  u'Bandelstra\xdfe',
#  'Bandkampsweg',
#  u'Bandwirkerstra\xdfe',
#  u'Banksstra\xdfe',
#  u'Bansenstra\xdfe',
#  'Bansgraben',
#  u'Barcastra\xdfe',
#  'Bargackerdamm',
#  u'Bargfredestra\xdfe',
#  'Bargweg',
#  'Barkendal',
#  u'Barlachstra\xdfe',
#  'Barlskamp',
#  'Barmbeker Markt',
#  u'Barmbeker Stra\xdfe',
#  'Barmwisch',
#  u'Barnerstra\xdfe',
#  u'Baron-Voght-Stra\xdfe',
#  u'Bartelsstra\xdfe',
#  'Bartensteiner Weg',
#  u'Bartholom\xe4usstra\xdfe',
#  u'Basedowstra\xdfe',
#  'Basselweg',
#  u'Baub\xfcrgerweg',
#  'Bauerberg',
#  'Bauerbergweg',
#  'Bauernholztal',
#  'Bauernrosenweg',
#  'Bauernstegel',
#  'Bauernweide',
#  'Baumacker',
#  u'Baumeisterstra\xdfe',
#  'Baumgarten',
#  'Baumkamp',
#  u'Bauml\xe4uferweg',
#  'Baumschulenweg',
#  'Baumtwiete',
#  'Baumwall',
#  'Baumweg',
#  'Baurs Park',
#  'Baurs Weg',
#  u'Baurstra\xdfe',
#  u'Baustra\xdfe',
#  'Bauvereinsweg',
#  u'Bauwiesenstra\xdfe',
#  'Bebelallee',
#  u'Bebelstra\xdfe',
#  u'Bechsteinstra\xdfe',
#  'Bechsteinweg',
#  u'Beckedorfer Stra\xdfe',
#  'Beckerberg',
#  'Beckers Treppe',
#  u'Beckmannstra\xdfe',
#  'Beckstedtweg',
#  u'Beckstra\xdfe',
#  u'Beerboomst\xfccken',
#  'Beerenberg',
#  'Beerenhain',
#  u'Beerenh\xf6he',
#  'Beerentaltrift',
#  'Beerentalweg',
#  'Beerenweg',
#  'Beethovenallee',
#  u'Beethovenstra\xdfe',
#  'Beetsweg',
#  'Begonienweg',
#  'Behnkenkammer',
#  u'Behnstra\xdfe',
#  'Behrensallee',
#  u'Behringstra\xdfe',
#  'Behrkampsweg',
#  'Behrmannplatz',
#  'Bei Schuldts Stift',
#  'Bei St. Annen',
#  'Bei St. Ansgar',
#  'Bei St. Johannis',
#  'Bei dem Neuen Krahn',
#  u'Bei den Landungsbr\xfccken',
#  u'Bei den M\xfchren',
#  u'Bei den Sankt-Pauli-Landungsbr\xfccken',
#  u'Bei den Schafst\xe4llen',
#  u'Bei den St. Pauli-Landungsbr\xfccken',
#  'Bei den Wettern',
#  'Bei den Zelten',
#  'Bei der Apostelkirche',
#  'Bei der Bergwettern',
#  'Bei der Christuskirche',
#  'Bei der Doppeleiche',
#  'Bei der Fischtreppe',
#  'Bei der Flottbeker Kirche',
#  u'Bei der Flottbeker M\xfchle',
#  'Bei der Friedenseiche',
#  'Bei der Hammer Kirche',
#  'Bei der Hauptfeuerwache',
#  'Bei der Johanniskirche',
#  'Bei der Kirche',
#  'Bei der Lutherbuche',
#  'Bei der Lutherkirche',
#  'Bei der Martinskirche',
#  u'Bei der Matth\xe4uskirche',
#  'Bei der Osterkirche',
#  'Bei der Paul-Gerhardt-Kirche',
#  'Bei der Pauluskirche',
#  'Bei der Petrikirche',
#  u'Bei der Pulverm\xfchle',
#  'Bei der Reitbahn',
#  u'Bei der Rolandsm\xfchle',
#  'Bei der Schilleroper',
#  'Bei der Schmiede',
#  u'Bei der Stadtwasserm\xfchle',
#  u'Bei der Windm\xfchle',
#  'Beim Alten Gaswerk',
#  u'Beim Alten Sch\xfctzenhof',
#  'Beim Amsinckpark',
#  'Beim Andreasbrunnen',
#  'Beim Avenberg',
#  'Beim Bergwerk',
#  'Beim Berliner Tor',
#  'Beim Bieberhof',
#  'Beim Brinkmarschen Park',
#  'Beim Dorfgraben',
#  'Beim Dorfkrug',
#  'Beim Elbkurhaus',
#  'Beim Findling',
#  'Beim Gesundbrunnen',
#  u'Beim Gr\xfcnen J\xe4ger',
#  'Beim Hammer Marktplatz',
#  'Beim Hirtenkaten',
#  'Beim Hoophof',
#  'Beim Jacobjstift',
#  'Beim Kraftwerk',
#  'Beim Opferstein',
#  'Beim Pachthof',
#  'Beim Rauhen Hause',
#  'Beim Schillingstift',
#  'Beim Schlump',
#  u'Beim Schr\xf6derschen Hof',
#  'Beim Strohhause',
#  'Beim Wilhelmsburger Wasserturm',
#  u'Beimoorstra\xdfe',
#  u'Beisserstra\xdfe',
#  'Bekassinenweg',
#  u'Bekstra\xdfe',
#  u'Bekst\xfcck',
#  'Bekweiden',
#  u'Bellealliancestra\xdfe',
#  'Bellerbek',
#  'Bellevue',
#  u'Bellmannstra\xdfe',
#  'Beltgens Garten',
#  'Bendestorfer Ring',
#  'Bendixensweg',
#  u'Benittstra\xdfe',
#  u'Bennigsenstra\xdfe',
#  'Benzenbergweg',
#  u'Benzstra\xdfe',
#  'Berchtungweg',
#  'Berenberg-Gossler-Weg',
#  'Bergedorfer Heerweg',
#  'Bergfeld',
#  'Bergheide',
#  u'Bergiusstra\xdfe',
#  'Bergkoppelweg',
#  u'Bergstra\xdfe',
#  'Bergwetternweg',
#  'Bergwinkel',
#  'Berkefeldweg',
#  'Berlepschkamp',
#  'Berlepschweg',
#  'Berliner Tor',
#  'Berlinertordamm',
#  u'Bernadottestra\xdfe',
#  'Bernburger Weg',
#  'Berner Chaussee',
#  u'Bernhard-Nocht-Stra\xdfe',
#  u'Bernstorffstra\xdfe',
#  'Bertha-Keyser-Weg',
#  'Bertha-Uhl-Kamp',
#  'Bertha-von-Suttner-Allee',
#  u'Berthastra\xdfe',
#  u'Bertrand-Russell-Stra\xdfe',
#  u'Berzeliusstra\xdfe',
#  'Beselerplatz',
#  u'Beselerstra\xdfe',
#  'Besenbinderhof',
#  'Besenheide',
#  'Besenreeg',
#  'Bessemerweg',
#  u'Bethesdastra\xdfe',
#  'Bettinastieg',
#  'Beutnerring',
#  'Bevenser Weg',
#  'Beyestieg',
#  u'Bi de Windm\xf6l',
#  'Bickbargen',
#  u'Bieberstra\xdfe',
#  'Biedermannplatz',
#  u'Bielfeldtstra\xdfe',
#  u'Biernatzkistra\xdfe',
#  'Biesterfeldweg',
#  'Billbrookdeich',
#  u'Billhorner Br\xfcckenstra\xdfe',
#  'Billhorner Deich',
#  u'Billhorner Kanalstra\xdfe',
#  u'Billhorner M\xfchlenweg',
#  u'Billhorner R\xf6hrendamm',
#  u'Billrothstra\xdfe',
#  u'Billstra\xdfe',
#  'Billwerder Neuer Deich',
#  'Billwerder Steindamm',
#  u'Bilser Stra\xdfe',
#  u'Binderstra\xdfe',
#  'Bindfeldweg',
#  'Bindsahl',
#  'Binnenfeld',
#  'Binsenort',
#  'Binsenweg',
#  'Birkenallee',
#  'Birkenau',
#  'Birkenbruch',
#  'Birkenhain',
#  'Birkenhang',
#  'Birkenweg',
#  'Birnweg',
#  'Bismarckstein',
#  u'Bismarckstra\xdfe',
#  u'Bissingstra\xdfe',
#  u'Bj\xf6rnsonweg',
#  u'Blangend\xf6\xf6r',
#  'Blankenburger Weg',
#  u'Blankeneser Bahnhofstra\xdfe',
#  'Blankeneser Chaussee',
#  u'Blankeneser Hauptstra\xdfe',
#  'Blankeneser Kirchenweg',
#  u'Blankeneser Landstra\xdfe',
#  'Blaubeerweg',
#  'Blaukehlchenweg',
#  'Blaukissenstieg',
#  'Blaumeisenweg',
#  u'Blechschmidtstra\xdfe',
#  u'Bleichenbr\xfccke',
#  u'Bleicherstra\xdfe',
#  'Bleicherweg',
#  'Bleickenallee',
#  u'Ble\xdfhuhnweg',
#  u'Blohmstra\xdfe',
#  'Blomkamp',
#  'Blumenau',
#  'Blumenpfad',
#  'Blumensand',
#  u'Blumenstra\xdfe',
#  'Blutbuchenweg',
#  u'Bl\xfccherstra\xdfe',
#  u'Bl\xfctenstieg',
#  u'Bl\xfctenweg',
#  u'Boberger Stra\xdfe',
#  u'Boberstra\xdfe',
#  'Bockhorst',
#  'Bockrisweg',
#  u'Bodelschwinghstra\xdfe',
#  u'Bodenstedtstra\xdfe',
#  'Boehringerweg',
#  'Bogenallee',
#  u'Bogenstra\xdfe',
#  'Bogenweg',
#  'Bohnenkamp',
#  u'Bohnstra\xdfe',
#  'Bollweg',
#  'Boltens Allee',
#  'Bondenwald',
#  u'Bonifatiusstra\xdfe',
#  u'Boninstra\xdfe',
#  u'Bonn\xe9weg',
#  u'Bonusstra\xdfe',
#  'Bookholtstwiete',
#  'Bookweetenkamp',
#  'Boomhof',
#  'Boothsweg',
#  'Borchersweg',
#  'Borchertring',
#  'Borchlingweg',
#  'Borgesch',
#  'Borgfelde',
#  'Borgfelder Allee',
#  u'Borgfelder Stra\xdfe',
#  'Borgweg',
#  'Borkenweg',
#  'Bornbergweg',
#  'Borndeel',
#  u'Bornemannstra\xdfe',
#  'Bornheide',
#  'Bornholdts Treppe',
#  'Bornkampsweg',
#  'Bornmoor',
#  u'Bornstra\xdfe',
#  'Borracks Weg',
#  u'Borselstra\xdfe',
#  u'Borsigstra\xdfe',
#  'Borsteler Bogen',
#  'Borsteler Chaussee',
#  'Borstelmannsweg',
#  'Borstels Ende',
#  u'Boschstra\xdfe',
#  'Boskoopstieg',
#  'Bosselkamp',
#  'Bostelbeker Damm',
#  'Bostelreihe',
#  u'Bothmannstra\xdfe',
#  u'Bovestra\xdfe',
#  'Bozenhardweg',
#  u'Bo\xdfdorfstra\xdfe',
#  'Braamkamp',
#  u'Brabandstra\xdfe',
#  'Brachetweg',
#  'Brachvogelweg',
#  'Brack',
#  'Brackdamm',
#  u'Brackh\xf6vel',
#  u'Brackstra\xdfe',
#  'Brackweg',
#  'Brahmhof',
#  'Brahmsallee',
#  'Brambarg',
#  'Brambuschweg',
#  'Bramfelder Chaussee',
#  'Bramfelder Dorfplatz',
#  'Bramfelder Drift',
#  u'Bramfelder Stra\xdfe',
#  'Bramweg',
#  u'Brandenburger Stra\xdfe',
#  'Brander Weg',
#  u'Brandesstra\xdfe',
#  'Brandfurt',
#  'Brandheide',
#  'Brandorffweg',
#  'Brandsende',
#  'Brandshofer Deich',
#  'Brandstwiete',
#  u'Brandst\xfccken',
#  'Brandts Weg',
#  'Brauereiweg',
#  'Brauerknechtgraben',
#  'Brauhausstieg',
#  u'Brauhausstra\xdfe',
#  'Braunlager Weg',
#  'Braunsberger Weg',
#  u'Braunschweiger Stra\xdfe',
#  u'Brau\xdfpark',
#  u'Breckwoldtstra\xdfe',
#  'Bredenbergsweg',
#  'Bredengrund',
#  'Bredenheider Weg',
#  'Bredensand',
#  'Bredenwinkel',
#  'Bredhornweg',
#  'Bredkamp',
#  u'Bredowstra\xdfe',
#  u'Bredstedter Stra\xdfe',
#  'Brehmweg',
#  u'Breite Stra\xdfe',
#  'Breitenbachweg',
#  u'Breitenfelder Stra\xdfe',
#  'Breiter Gang',
#  'Breiter Weg',
#  'Breitscheidweg',
#  'Brekelbaums Park',
#  'Bremer Kai',
#  'Bremer Reihe',
#  u'Bremer Stra\xdfe',
#  'Bremers Weg',
#  'Brennerhof',
#  u'Brennerstra\xdfe',
#  u'Breslauer Stra\xdfe',
#  'Briggweg',
#  u'Brigittenstra\xdfe',
#  'Brillenburgskamp',
#  'Brillenburgsweg',
#  u'Brinkst\xfccken',
#  'Brockmanns Weg',
#  'Brockmannsweg',
#  u'Brodersenstra\xdfe',
#  'Brodersweg',
#  'Brodschrangen',
#  'Brombeerstieg',
#  'Brombeerweg',
#  u'Bromberger Stra\xdfe',
#  'Broockkampsweg',
#  'Broocksdamm',
#  'Brook',
#  'Brookdamm',
#  'Brooksheide',
#  'Brooktorkai',
#  'Brookwisch',
#  'Bruchloh',
#  u'Brucknerstra\xdfe',
#  'Brummerredder',
#  'Brummerskamp',
#  'Brunckhorstweg',
#  u'Brunhildstra\xdfe',
#  u'Brunnenhofstra\xdfe',
#  'Brunnenstieg',
#  'Bruno-Georges-Platz',
#  'Brunsberg',
#  u'Brunsstra\xdfe',
#  u'Br\xe4sigweg',
#  u'Br\xf6dermannsweg',
#  u'Br\xf6ers Treppe',
#  u'Br\xfcckwiesenstra\xdfe',
#  u'Br\xfcderstra\xdfe',
#  u'Br\xfcggemannsweg',
#  u'Br\xfcningstra\xdfe',
#  u'Br\xfcnschentwiete',
#  'Bubendeyweg',
#  'Buchenallee',
#  'Buchenhof',
#  u'Buchenstra\xdfe',
#  'Buchenweg',
#  u'Buchheisterstra\xdfe',
#  'Buchholzer Weg',
#  'Buchsbaumweg',
#  u'Buchtstra\xdfe',
#  u'Budapester Stra\xdfe',
#  u'Buddestra\xdfe',
#  'Buekweg',
#  u'Bugdahnstra\xdfe',
#  u'Bugenhagenstra\xdfe',
#  u'Bulckestra\xdfe',
#  'Bullenhuser Damm',
#  'Bullerdeich',
#  'Bullnwisch',
#  'Bunatwiete',
#  u'Bundesstra\xdfe',
#  'Bundesweg',
#  'Bundsensweg',
#  u'Bunsenstra\xdfe',
#  'Buntspechtweg',
#  u'Burbekstra\xdfe',
#  'Burchardplatz',
#  u'Burchardstra\xdfe',
#  'Burggarten',
#  u'Burgstra\xdfe',
#  'Burgunderweg',
#  'Burgweg',
#  u'Burmesterstra\xdfe',
#  'Buschkamp',
#  'Buschkoppel',
#  'Buschredder',
#  'Buschrosenweg',
#  'Buschweg',
#  'Buschwerder Winkel',
#  'Bussardweg',
#  u'Bussestra\xdfe',
#  'Butendeichsweg',
#  'Butendieksweg',
#  'Butenfeld',
#  u'Buttstra\xdfe',
#  u'Buxtehuder Stra\xdfe',
#  u'B\xe4ckerbreitergang',
#  u'B\xe4ckerstra\xdfe',
#  u'B\xe4renallee',
#  u'B\xf6ckelweg',
#  u'B\xf6cklinstra\xdfe',
#  u'B\xf6ckmannstra\xdfe',
#  u'B\xf6hmersweg',
#  u'B\xf6hmestra\xdfe',
#  u'B\xf6hmkenstra\xdfe',
#  u'B\xf6kenkamp',
#  u'B\xf6melburgstieg',
#  u'B\xf6melburgweg',
#  u'B\xf6rnestra\xdfe',
#  u'B\xf6rsenbr\xfccke',
#  u'B\xf6telkamp',
#  u'B\xf6ttcherkamp',
#  u'B\xf6ttgerstra\xdfe',
#  u'B\xf6verstland',
#  u'B\xfclaustra\xdfe',
#  u'B\xfclowstieg',
#  u'B\xfclowstra\xdfe',
#  u'B\xfcltenweg',
#  u'B\xfcndtwiete',
#  u'B\xfcngerweg',
#  u'B\xfcnte',
#  u'B\xfcrgermeister-Hagemann-Weg',
#  u'B\xfcrgermeister-Heitmann-Stra\xdfe',
#  u'B\xfcrgermeister-Wittwer-Weg',
#  u'B\xfcrgerstra\xdfe',
#  u'B\xfcrgerweide',
#  u'B\xfcringstwiete',
#  u'B\xfcschstra\xdfe',
#  'Caffamacherreihe',
#  u'Caprivistra\xdfe',
#  'Carl-Bremer-Ring',
#  u'Carl-Cohn-Stra\xdfe',
#  u'Carl-Hermann-Richter-Stra\xdfe',
#  u'Carl-Petersen-Stra\xdfe',
#  u'Carl-Zeiss-Stra\xdfe',
#  u'Carlebachstra\xdfe',
#  'Carpserweg',
#  'Carsten-Fock-Weg',
#  u'Carsten-Rehder-Stra\xdfe',
#  u'Caspar-Voght-Stra\xdfe',
#  'Catharina-Gerkens-Weg',
#  'Celsiusweg',
#  'Chamissoweg',
#  'Chapeaurougeweg',
#  'Charitas-Bischoff-Treppe',
#  u'Charlotte-Niese-Stra\xdfe',
#  u'Charlottenstra\xdfe',
#  u'Chateauneufstra\xdfe',
#  u'Chemnitzstra\xdfe',
#  'Cheruskerweg',
#  'Christian-August-Weg',
#  u'Christian-Frederik-Hansen-Stra\xdfe',
#  u'Christian-F\xf6rster-Stra\xdfe',
#  u'Christoph-Cordes-Stra\xdfe',
#  'Christoph-Probst-Weg',
#  'Cilli-Cohrs-Weg',
#  ...]

# %% [markdown]
# <a id="13"></a>
# ## Data Overview and Additional Ideas
# ***
#
# ### Create SQL3Lite database to save XML content

# %%
#dbUdacity = mySQLLITE3('C:\\Users\\th65jt\\sqlite3\\', 'osmHamburg.db')
dbUdacity = mySQLLITE3('C:\\Users\\JanUser\\sqlite\\sqlite_windows\\', 'osmHamburg.db')

#dbUdacity.execute_SQLStatementsFile('C:\\Users\\JanUser\\Documents\\Udacity\\Sybullus\\L3 MongoDB\\Project\\OSM_Drop_Tables.sql')
#dbUdacity.commit_SQL()

#dbUdacity.execute_SQLStatementsFile('OSM_Create_Tables.sql')
#dbUdacity.import_preformatted_CSV('.\\nodes.csv', 'nodes')
#dbUdacity.import_preformatted_CSV('.\\nodes_tags.csv', 'nodes_tags')
#dbUdacity.import_preformatted_CSV('.\\ways.csv', 'ways')
#dbUdacity.import_preformatted_CSV('.\\ways_tags.csv', 'ways_tags')
#dbUdacity.import_preformatted_CSV('.\\ways_nodes.csv', 'ways_nodes')

# %%
dbUdacity.query_AllResults('''SELECT nodes_tags.key                                
                                , count(nodes_tags.key) as sum
                           FROM nodes_tags
                           GROUP BY nodes_tags.key
                           ORDER BY sum DESC;''')
# Out:
# [(u'street', 34999),
#  (u'housenumber', 34616),
#  (u'postcode', 28577),
#  (u'city', 26874),
#  (u'natural', 24232),
#  (u'name', 22760),
#  (u'country', 22093),
#  (u'entrance', 15777),
#  (u'highway', 15071),
#  (u'amenity', 15049),
#  (u'type', 11967),
#  (u'ref', 8454),
#  (u'wheelchair', 8033),
#  (u'railway', 7596),
#  (u'network', 6510),
#  (u'shop', 5943),
#  (u'emergency', 5523),
#  (u'diameter', 4890),
#  (u'operator', 4695),
#  (u'barrier', 4190),
#  (u'historic', 4111),
#  (u'website', 4076),
#  (u'source', 4034),
#  (u'position', 3929),
#  (u'opening_hours', 3901),
#  (u'addr', 3755),
#  (u'crossing', 3416),
#  (u'phone', 3223),
#  (u'bus', 3207),
#  (u'signal:direction', 3177),
#  (u'signal:position', 3163),
#  (u'level', 2720),
#  (u'public_transport', 2270),
#  (u'leaf_type', 2267),
#  (u'date_of_birth', 2039),
#  (u'addr:city', 1904),
#  (u'addr:street', 1895),
#  (u'created_by', 1757),
#  (u'note', 1717),
#  (u'bicycle', 1583),
#  (u'text', 1581),
#  (u'shelter', 1550),
#  (u'cuisine', 1547),
#  (u'description', 1515),
#  (u'check_date', 1492),
#  (u'switch', 1460),
#  (u'mooring:category', 1443),
#  (u'de', 1433),
#  (u'signal:minor:form', 1365),
#  (u'signal:minor', 1361),
#  (u'local_operated', 1359),
#  (u'ele', 1301),
#  (u'cid_58:tabcd_1:LocationCode', 1290),
#  (u'cid_58:tabcd_1:Class', 1289),
#  (u'cid_58:tabcd_1:LCLversion', 1288),
#  (u'switch:electric', 1267),
#  (u'cid_58:tabcd_1:Direction', 1256),
#  (u'suburb', 1241),
#  (u'switch:resetting', 1211),
#  (u'access', 1196),
#  (u'cid_58:tabcd_1:NextLocationCode', 1178),
#  (u'cid_58:tabcd_1:PrevLocationCode', 1163),
#  (u'foot', 1107),
#  (u'addr:postcode', 1035),
#  (u'collection_times', 1014),
#  (u'tourism', 988),
#  (u'genus', 944),
#  (u'signal:minor:height', 936),
#  (u'power', 881),
#  (u'signal:minor:states', 863),
#  (u'man_made', 861),
#  (u'vending', 831),
#  (u'recycling_type', 801),
#  (u'building', 744),
#  (u'leisure', 735),
#  (u'traffic_sign', 699),
#  (u'signal:main', 691),
#  (u'signal:main:form', 690),
#  (u'crossing_ref', 671),
#  (u'backrest', 656),
#  (u'paper', 637),
#  (u'email', 619),
#  (u'capacity', 615),
#  (u'covered', 580),
#  (u'signal:distant', 574),
#  (u'signal:distant:form', 571),
#  (u'fee', 556),
#  (u'layer', 555),
#  (u'internet_access', 549),
#  (u'pressure', 546),
#  (u'coins', 529),
#  (u'signal:distant:shortened', 520),
#  (u'signal:main:height', 499),
#  (u'surveillance', 488),
#  (u'parking', 485),
#  (u'signal:distant:height', 483),
#  (u'office', 482),
#  (u'signal:main:states', 481),
#  (u'material', 453),
#  (u'signal:main:function', 433),
#  (u'addr:housenumber', 430),
#  (u'signal:distant:repeated', 427),
#  (u'credit_cards', 414),
#  (u'route_ref', 409),
#  (u'signal:combined', 408),
#  (u'signal:combined:form', 408),
#  (u'fax', 404),
#  (u'lastcheck', 398),
#  (u'advertising', 397),
#  (u'indoor', 396),
#  (u'signal:combined:height', 385),
#  (u'signal:distant:states', 384),
#  (u'species', 382),
#  (u'signal:combined:function', 370),
#  (u'telephone_cards', 370),
#  (u'sms', 360),
#  (u'signal:combined:states', 356),
#  (u'mount', 344),
#  (u'glass', 341),
#  (u'leaf_cycle', 334),
#  (u'subway', 330),
#  (u'fixme', 324),
#  (u'milestone:catenary_mast', 322),
#  (u'seats', 299),
#  (u'milestone:emergency_brake_override', 288),
#  (u'signal:speed_limit:form', 284),
#  (u'signal:speed_limit', 283),
#  (u'clothes', 278),
#  (u'light', 271),
#  (u'smoking', 270),
#  (u'glass_bottles', 266),
#  (u'switch:heated', 261),
#  (u'bench', 250),
#  (u'passenger_information_display', 248),
#  (u'date', 247),
#  (u'signal:speed_limit:speed', 244),
#  (u'atm', 242),
#  (u'brand', 239),
#  (u'alt_name', 235),
#  (u'wikipedia', 233),
#  (u'direction', 220),
#  (u'place', 220),
#  (u'signal:speed_limit:height', 215),
#  (u'addr:suburb', 206),
#  (u'bicycle_parking', 204),
#  (u'obstacle', 202),
#  (u'colour', 200),
#  (u'turnout_side', 197),
#  (u'bell', 196),
#  (u'craft', 195),
#  (u'dispensing', 192),
#  (u'information', 191),
#  (u'image', 186),
#  (u'obstacle_name', 183),
#  (u'date_of_death', 181),
#  (u'saltire', 179),
#  (u'bridge:category', 171),
#  (u'light:colour', 165),
#  (u'light:character', 164),
#  (u'takeaway', 157),
#  (u'signal:main:substitute_signal', 152),
#  (u'sport', 150),
#  (u'noexit', 149),
#  (u'start_date', 148),
#  (u'signal:stop', 146),
#  (u'signal:stop:form', 146),
#  (u'light_rail', 145),
#  (u'housename', 144),
#  (u'psv_type', 142),
#  (u'switch:movable_frog', 142),
#  (u'outdoor_seating', 141),
#  (u'pipeline', 139),
#  (u'height', 138),
#  (u'is_in', 137),
#  (u'signal:speed_limit_distant', 136),
#  (u'barrier_free', 135),
#  (u'traffic_calming', 133),
#  (u'distance', 131),
#  (u'healthcare', 131),
#  (u'count', 130),
#  (u'signal:speed_limit_distant:form', 129),
#  (u'bridge:clearance_height', 128),
#  (u'manufacturer', 125),
#  (u'signal:combined:substitute_signal', 123),
#  (u'notes', 119),
#  (u'isil', 118),
#  (u'signal:main:deactivated', 118),
#  (u'postal_code', 113),
#  (u'signal:departure', 113),
#  (u'signal:departure:form', 113),
#  (u'signal:departure:states', 113),
#  (u'tactile_paving', 111),
#  (u'time', 111),
#  (u'artist_name', 110),
#  (u'chicane', 110),
#  (u'since', 110),
#  (u'signal:minor:deactivated', 108),
#  (u'speciality', 108),
#  (u'signal:stop:height', 107),
#  (u'delivery', 104),
#  (u'zone', 104),
#  (u'location', 103),
#  (u'on_demand', 102),
#  (u's-train', 96),
#  (u'support', 95),
#  (u'display', 94),
#  (u'playground', 92),
#  (u'en', 91),
#  (u'motorcar', 91),
#  (u'signal:speed_limit_distant:height', 91),
#  (u'artwork_type', 90),
#  (u'notice:category', 90),
#  (u'signal:distant:deactivated', 90),
#  (u'signal:speed_limit_distant:speed', 90),
#  (u'waterway', 90),
#  (u'light:period', 89),
#  (u'signal:combined:marker_light', 89),
#  (u'signal:combined:deactivated', 88),
#  (u'signal:electricity:form', 88),
#  (u'notice:function', 87),
#  (u'signal:electricity', 87),
#  (u'signal:electricity:type', 87),
#  (u'motorcycle', 83),
#  (u'small_appliances', 83),
#  (u'train', 83),
#  (u'signal:stop:caption', 82),
#  (u'seamark', 81),
#  (u'voltage', 80),
#  (u'religion', 79),
#  (u'signal:wrong_road', 77),
#  (u'signal:wrong_road:form', 77),
#  (u'signal:electricity:height', 75),
#  (u'notice:orientation', 73),
#  (u'community_identification_number', 71),
#  (u'loc_id', 71),
#  (u'license_plate_code', 70),
#  (u'uic_name', 70),
#  (u'uic_ref', 69),
#  (u'for', 68),
#  (u'hha_ref', 67),
#  (u'population', 66),
#  (u'url', 66),
#  (u'denotation', 65),
#  (u'local_ref', 64),
#  (u'military', 64),
#  (u'wheelchair_toilet', 64),
#  (u'buoy_lateral:category', 63),
#  (u'buoy_lateral:colour', 63),
#  (u'official_name', 63),
#  (u'amperage', 62),
#  (u'motor_vehicle', 62),
#  (u'buoy', 60),
#  (u'buoy_lateral:shape', 59),
#  (u'station_category', 59),
#  (u'mobile_phone', 58),
#  (u'buoy_lateral:system', 57),
#  (u'postal_codes', 57),
#  (u'signal:shunting', 57),
#  (u'signal:shunting:form', 57),
#  (u'waste_basket', 57),
#  (u'plug', 55),
#  (u'horse', 54),
#  (u'activation', 53),
#  (u'signal:electricity:turn_direction', 53),
#  (u'short_name', 52),
#  (u'waterway_distance', 52),
#  (u'asb', 51),
#  (u'button_operated', 51),
#  (u'onkz', 51),
#  (u'electronic_purses', 50),
#  (u'hamburgenergie', 50),
#  (u'social_facility', 50),
#  (u'vattenfall', 50),
#  (u'vegan', 50),
#  (u'wikidata', 49),
#  (u'EUR', 48),
#  (u'debit_cards', 47),
#  (u'distance_mark:category', 47),
#  (u'distance_mark:distance', 47),
#  (u'distance_mark:units', 47),
#  (u'organic', 46),
#  (u'position:exact', 46),
#  (u'cemetery', 45),
#  (u'faces', 45),
#  (u'lpg', 45),
#  (u'plastic', 45),
#  (u'sound', 45),
#  (u'bin', 44),
#  (u'denomination', 44),
#  (u'inscription', 44),
#  (u'memorial', 43),
#  (u'signal:route', 43),
#  (u'signal:route:form', 43),
#  (u'octane_95', 42),
#  (u'output:electricity', 42),
#  (u'diesel', 41),
#  (u'district', 41),
#  (u'maxspeed', 41),
#  (u'plastic_packaging', 41),
#  (u'signal:brake_test', 41),
#  (u'signal:brake_test:form', 41),
#  (u'signal:brake_test:states', 41),
#  (u'signal:shunting:height', 40),
#  (u'angle', 39),
#  (u'buoy_special_purpose:colour', 38),
#  (u'light:group', 38),
#  (u'signal:route:states', 38),
#  (u'stars', 38),
#  (u'board_type', 37),
#  (u'buoy_special_purpose:shape', 37),
#  (u'method', 37),
#  (u'signal:combined:shortened', 37),
#  (u'signal:whistle', 37),
#  (u'signal:whistle:form', 37),
#  (u'signal:whistle:only_transit', 37),
#  (u'signal:whistle:twice', 37),
#  (u'signal:crossing:form', 36),
#  (u'signal:speed_limit:deactivated', 36),
#  (u'drive_in', 35),
#  (u'drive_through', 35),
#  (u'radius', 35),
#  (u'supervision', 35),
#  (u'bus_lines', 34),
#  (u'lines', 34),
#  (u'octane_98', 34),
#  (u'cash', 33),
#  (u'feature', 33),
#  (u'levels', 33),
#  (u'street_cabinet', 33),
#  (u'light:height', 32),
#  (u'light:range', 32),
#  (u'old_name', 32),
#  (u'surface', 32),
#  (u'vegetarian', 32),
#  (u'year', 32),
#  (u'FIXME', 31),
#  (u'pos', 31),
#  (u'beacon_lateral:category', 30),
#  (u'beacon_lateral:colour', 30),
#  (u'beacon_lateral:shape', 29),
#  (u'filter', 29),
#  (u'lamp_type', 29),
#  (u'maxheight', 29),
#  (u'sign', 29),
#  (u'signal:crossing:shortened', 29),
#  (u'signal:main_repeated', 29),
#  (u'signal:main_repeated:form', 29),
#  (u'supervised', 29),
#  (u'daymark:colour', 28),
#  (u'daymark:shape', 28),
#  (u'diplomatic', 28),
#  (u'door', 28),
#  (u'e10', 28),
#  (u'signal:crossing:repeated', 28),
#  (u'aeroway', 27),
#  (u'bollard', 27),
#  (u'maxspeed:diverging', 27),
#  (u'signal:main_repeated:deactivated', 27),
#  (u'vibration', 27),
#  (u'disabled', 26),
#  (u'light:category', 26),
#  (u'location:de', 26),
#  (u'signal:crossing', 26),
#  (u'signal:crossing:states', 26),
#  (u'design_count', 25),
#  (u'ferry', 25),
#  (u'set', 25),
#  (u'shoes', 25),
#  (u'signal:brake_test:deactivated', 25),
#  (u'end_date', 24),
#  (u'notice:addition', 24),
#  (u'traffic_signals', 24),
#  (u'tunnelsystem_jungfernstieg', 24),
#  (u'day_date', 23),
#  (u'entrance_name', 23),
#  (u'signal:departure:deactivated', 23),
#  (u'source_ref', 23),
#  (u'cans', 22),
#  (u'heritage', 22),
#  (u'light:orientation', 22),
#  (u'signal:distant:marker_light', 22),
#  (u'station', 22),
#  (u'cartons', 21),
#  (u'converted_by', 21),
#  (u'derail', 21),
#  (u'lit', 21),
#  (u'segregated', 21),
#  (u'shelter_type', 21),
#  (u'topmark:shape', 21),
#  (u'frequency', 20),
#  (u'paper_packaging', 20),
#  (u'signal:traversable', 20),
#  (u'signal:traversable:type', 20),
#  (u'cutting', 19),
#  (u'map_size', 19),
#  (u'mobile', 19),
#  (u'park_ride', 19),
#  (u'platform:section', 19),
#  (u'position:direction', 19),
#  (u'signal:stop:deactivated', 19),
#  (u'beauty', 18),
#  (u'cng', 18),
#  (u'maestro', 18),
#  (u'maxspeed:straight', 18),
#  (u'wifi', 18),
#  (u'HGV_diesel', 17),
#  (u'books', 17),
#  (u'club-mate', 17),
#  (u'facebook', 17),
#  (u'magazines', 17),
#  (u'newspaper', 17),
#  (u'second_hand', 17),
#  (u'signal:minor:marker_light', 17),
#  (u'signal:wrong_road:deactivated', 17),
#  (u'site_type', 17),
#  (u'topmark', 17),
#  (u'bicycle:repair', 16),
#  (u'guidepost', 16),
#  (u'lwn_ref', 16),
#  (u'microbrewery', 16),
#  (u'octane_100', 16),
#  (u'operator_inventory', 16),
#  (u'planed', 16),
#  (u'scrap_metal', 16),
#  (u'signal:crossing_info', 16),
#  (u'small_craft_facility:category', 16),
#  (u'GTL_diesel', 15),
#  (u'bitcoin', 15),
#  (u'cardboard', 15),
#  (u'daymark:colour_pattern', 15),
#  (u'embankment', 15),
#  (u'harbour:category', 15),
#  (u'octane_91', 15),
#  (u'ref_name', 15),
#  (u'signal:crossing_distant', 15),
#  (u'signal:crossing_distant:form', 15),
#  (u'signal:crossing_info:caption', 15),
#  (u'signal:crossing_info:form', 15),
#  (u'signal:crossing_info:repeated', 15),
#  (u'visibility', 15),
#  (u'width', 15),
#  (u'batteries', 14),
#  (u'girocard', 14),
#  (u'int_name', 14),
#  (u'signal:crossing_distant:shortened', 14),
#  (u'topmark:colour', 14),
#  (u'type2', 14),
#  (u'car', 13),
#  (u'club', 13),
#  (u'construction', 13),
#  (u'male', 13),
#  (u'manufacturer_inventory', 13),
#  (u'origin', 13),
#  (u'plate', 13),
#  (u'signal:crossing_distant:repeated', 13),
#  (u'signal:route_distant', 13),
#  (u'signal:route_distant:form', 13),
#  (u'kilometer', 12),
#  (u'signal:crossing_info:height', 12),
#  (u'vehicle', 12),
#  (u'visa', 12),
#  (u'diaper', 11),
#  (u'ft_symbol', 11),
#  (u'green_waste', 11),
#  (u'membership_card', 11),
#  (u'plastic_bottles', 11),
#  (u'signal:speed_limit_distant:deactivated', 11),
#  (u'bicycle:retail', 10),
#  (u'electrical_appliances', 10),
#  (u'emergency_telephone_code', 10),
#  (u'food', 10),
#  (u'landuse', 10),
#  (u'mastercard', 10),
#  (u'name:DB', 10),
#  (u'self_service', 10),
#  (u'service', 10),
#  (u'studio', 10),
#  (u'waste', 10),
#  (u'account_cards', 9),
#  (u'disused', 9),
#  (u'ep_geldkarte', 9),
#  (u'female', 9),
#  (u'government', 9),
#  (u'light:1:character', 9),
#  (u'light:1:colour', 9),
#  (u'maxwidth', 9),
#  (u'parking_space', 9),
#  (u'ref:DB', 9),
#  (u'schuko', 9),
#  (u'scooter', 9),
#  (u'shape', 9),
#  (u'signal:expected_position', 9),
#  (u'signal:route_distant:states', 9),
#  (u'signal:whistle:deactivated', 9),
#  (u'substation', 9),
#  (u'wood', 9),
#  (u'app', 8),
#  (u'beacon', 8),
#  (u'car_wash', 8),
#  (u'dsa', 8),
#  (u'gambling', 8),
#  (u'massage', 8),
#  (u'maxweight', 8),
#  (u'proposed', 8),
#  (u'ru', 8),
#  (u'short_message', 8),
#  (u'short_message:number', 8),
#  (u'short_message:text', 8),
#  (u'signal:route:deactivated', 8),
#  (u'unisex', 8),
#  (u'vhf', 8),
#  (u'wine', 8),
#  (u'bicycle:pump', 7),
#  (u'criteria', 7),
#  (u'disposal', 7),
#  (u'flag', 7),
#  (u'gay', 7),
#  (u'kerb', 7),
#  (u'landmark:category', 7),
#  (u'light:1:sector_end', 7),
#  (u'light:1:sector_start', 7),
#  (u'light:2:character', 7),
#  (u'light:2:colour', 7),
#  (u'light:reference', 7),
#  (u'maxstay', 7),
#  (u'model_railway', 7),
#  (u'power_source', 7),
#  (u'ref:count', 7),
#  (u'signal:expected_position:height', 7),
#  (u'signal:radio', 7),
#  (u'signal:radio:form', 7),
#  (u'signal:shunting:states', 7),
#  (u'sloped_curb', 7),
#  (u'survey_date', 7),
#  (u'telephone_area_code', 7),
#  (u'amtlicher_gemeindeschluessel', 6),
#  (u'arbeitstag', 6),
#  (u'artist', 6),
#  (u'artist_life', 6),
#  (u'bicycle:second_hand', 6),
#  (u'description:de', 6),
#  (u'design', 6),
#  (u'electricity', 6),
#  (u'enforcement', 6),
#  (u'gate:category', 6),
#  (u'hiking', 6),
#  (u'it', 6),
#  (u'key_switch:crossing', 6),
#  (u'key_switch:crossing:usage', 6),
#  (u'lcn', 6),
#  (u'light:1:period', 6),
#  (u'map_type', 6),
#  (u'ref:parent', 6),
#  (u'repeat_on', 6),
#  (u'rooms', 6),
#  (u'service_times', 6),
#  (u'signal:radio:frequency', 6),
#  (u'structure', 6),
#  (u'voltage-high', 6),
#  (u'zh', 6),
#  (u'1_25', 5),
#  (u'1_50', 5),
#  (u'bicycle:rental', 5),
#  (u'biodiesel', 5),
#  (u'buoy_special_purpose:category', 5),
#  (u'collection_times:lastcheck', 5),
#  (u'comment', 5),
#  (u'delivery_date', 5),
#  (u'dogs', 5),
#  (u'e85', 5),
#  (u'ft_link', 5),
#  (u'key_switch:crossing:type', 5),
#  (u'light:1:height', 5),
#  (u'light:2:period', 5),
#  (u'light:2:sector_end', 5),
#  (u'light:2:sector_start', 5),
#  (u'mobil-parken.de', 5),
#  (u'nds', 5),
#  (u'owner', 5),
#  (u'power_supply', 5),
#  (u'toilets', 5),
#  (u'tower', 5),
#  (u'vacant', 5),
#  (u'abandoned', 4),
#  (u'adblue', 4),
#  (u'alt_name_1', 4),
#  (u'architect', 4),
#  (u'area', 4),
#  (u'autogas', 4),
#  (u'automated', 4),
#  (u'baby', 4),
#  (u'bar', 4),
#  (u'biogas', 4),
#  (u'brewery', 4),
#  (u'bufa', 4),
#  (u'busbar', 4),
#  (u'cables', 4),
#  (u'cid_58:tabcd_1:TypeName', 4),
#  (u'cid_58:tabcd_1:TypeName:loc', 4),
#  (u'conditional', 4),
#  (u'designation', 4),
#  (u'dkv', 4),
#  (u'drinking_water', 4),
#  (u'fa', 4),
#  (u'floor', 4),
#  (u'fog_signal:category', 4),
#  (u'fog_signal:period', 4),
#  (u'format', 4),
#  (u'fuel_cards', 4),
#  (u'full_name', 4),
#  (u'gate:clearance_height', 4),
#  (u'gauge:h0', 4),
#  (u'genre', 4),
#  (u'google_plus', 4),
#  (u'hotspot_id', 4),
#  (u'is_in_loc_id', 4),
#  (u'landmark:conspicuity', 4),
#  (u'light:1:range', 4),
#  (u'light:2:height', 4),
#  (u'light:2:range', 4),
#  (u'loc_ref', 4),
#  (u'lottery', 4),
#  (u'min_age', 4),
#  (u'music_genre', 4),
#  (u'payment:coins', 4),
#  (u'phases', 4),
#  (u'reference', 4),
#  (u'rotate', 4),
#  (u'shop_1', 4),
#  (u'signal:catenary_mast', 4),
#  (u'signal:crossing:deactivated', 4),
#  (u'signal:route_distant:deactivated', 4),
#  (u'signal:shunting:deactivated', 4),
#  (u'signal:speed_limit_distant:turn_direction', 4),
#  (u'step_count', 4),
#  (u'style', 4),
#  (u'substance', 4),
#  (u'top', 4),
#  (u'transformer', 4),
#  (u'uk', 4),
#  (u'uta', 4),
#  (u'voltage-low', 4),
#  (u'wpt_symbol', 4),
#  (u'automatic_door', 3),
#  (u'barrier_free_psv_types', 3),
#  (u'boundary', 3),
#  (u'bridge:clearance_height_closed', 3),
#  (u'bundesfinanzamtnummer', 3),
#  (u'buoy_lateral:colour_pattern', 3),
#  (u'buoy_special_purpose:colour_pattern', 3),
#  (u'centralkey', 3),
#  (u'chademo', 3),
#  (u'charge', 3),
#  (u'community_centre', 3),
#  (u'construction_year', 3),
#  (u'cryptocurrencies', 3),
#  (u'ebusinesslotse', 3),
#  (u'education', 3),
#  (u'electrical_items', 3),
#  (u'es', 3),
#  (u'fog_signal:group', 3),
#  (u'fr', 3),
#  (u'fuel', 3),
#  (u'gauge:z', 3),
#  (u'gluten_free', 3),
#  (u'harbour', 3),
#  (u'health_insurance', 3),
#  (u'landmark', 3),
#  (u'laundry_service', 3),
#  (u'license_classes', 3),
#  (u'line', 3),
#  (u'loc_name', 3),
#  (u'long_name', 3),
#  (u'lunch', 3),
#  (u'manometer', 3),
#  (u'model', 3),
#  (u'music', 3),
#  (u'musical_instrument', 3),
#  (u'note:de', 3),
#  (u'octane_102', 3),
#  (u'others', 3),
#  (u'phone:mobile', 3),
#  (u'physiotherapy', 3),
#  (u'price', 3),
#  (u'profil', 3),
#  (u'rail', 3),
#  (u'railway_crossing:movable_frog', 3),
#  (u'ref:HPA', 3),
#  (u'relation', 3),
#  (u'role', 3),
#  (u'sanitary_dump_station', 3),
#  (u'shower', 3),
#  (u'signal:crossing_hint', 3),
#  (u'signal:crossing_hint:caption', 3),
#  (u'signal:crossing_hint:form', 3),
#  (u'signal:crossing_hint:height', 3),
#  (u'signal:crossing_hint:repeated', 3),
#  (u'signal:main:marker_light', 3),
#  (u'slogan', 3),
#  (u'smoothness', 3),
#  (u'target', 3),
#  (u'tree', 3),
#  (u'university', 3),
#  (u'website_1', 3),
#  (u'women', 3),
#  (u'year_of_construction', 3),
#  (u'LOCODE', 2),
#  (u'Skate_equipment', 2),
#  (u'air_quality', 2),
#  (u'american_express', 2),
#  (u'basketball_backboards', 2),
#  (u'basketswing', 2),
#  (u'be', 2),
#  (u'beacon_cardinal:category', 2),
#  (u'beacon_cardinal:colour', 2),
#  (u'beacon_cardinal:colour_pattern', 2),
#  (u'beacon_cardinal:shape', 2),
#  (u'bicycle:cleaning', 2),
#  (u'bike_ride', 2),
#  (u'bos', 2),
#  (u'breakfast', 2),
#  (u'bridge:clearance_height_open', 2),
#  (u'bus_ticket', 2),
#  (u'canoe', 2),
#  (u'car_service', 2),
#  (u'chain_ladder', 2),
#  (u'chess_table', 2),
#  (u'climb_wall', 2),
#  (u'climbingframe', 2),
#  (u'cocktails', 2),
#  (u'cost', 2),
#  (u'country_code', 2),
#  (u'coupling_type', 2),
#  (u'cs', 2),
#  (u'cushion', 2),
#  (u'darts', 2),
#  (u'death', 2),
#  (u'desc', 2),
#  (u'diet', 2),
#  (u'direction_northwest', 2),
#  (u'dog', 2),
#  (u'donator', 2),
#  (u'electrified', 2),
#  (u'elevator', 2),
#  (u'entrqy', 2),
#  (u'eo', 2),
#  (u'excrement_bags', 2),
#  (u'exhibit', 2),
#  (u'fair_trade', 2),
#  (u'fare_zone', 2),
#  (u'fireplace', 2),
#  (u'furniture', 2),
#  (u'gauge', 2),
#  (u'hazard', 2),
#  (u'hoops', 2),
#  (u'hopscotch', 2),
#  (u'hvv_service', 2),
#  (u'importance', 2),
#  (u'instagram', 2),
#  (u'internet', 2),
#  (u'ja', 2),
#  (u'judical_level', 2),
#  (u'ko', 2),
#  (u'landmark:function', 2),
#  (u'lawyer', 2),
#  (u'lift_gate', 2),
#  (u'light:3:character', 2),
#  (u'light:3:colour', 2),
#  (u'light:3:height', 2),
#  (u'light:3:period', 2),
#  (u'light:3:range', 2),
#  (u'light:3:sector_end', 2),
#  (u'light:3:sector_start', 2),
#  (u'limit', 2),
#  (u'lock_name', 2),
#  (u'max_age', 2),
#  (u'monument', 2),
#  (u'multi_play', 2),
#  (u'music:cd', 2),
#  (u'music:new', 2),
#  (u'music:vinyl', 2),
#  (u'nails', 2),
#  (u'name_1', 2),
#  (u'none', 2),
#  (u'notice:1:category', 2),
#  (u'notice:1:function', 2),
#  (u'notice:2:category', 2),
#  (u'notice:2:function', 2),
#  (u'notice:system', 2),
#  (u'nudism', 2),
#  (u'output:steam', 2),
#  (u'overhead_line', 2),
#  (u'parent', 2),
#  (u'payment', 2),
#  (u'payment:credit_cards', 2),
#  (u'payment:telephone_cards', 2),
#  (u'plastic_packages', 2),
#  (u'playhouse', 2),
#  (u'post_office', 2),
#  (u'pt', 2),
#  (u'pumping_station', 2),
#  (u'radio', 2),
#  (u'recycling:glass', 2),
#  (u'recycling:paper', 2),
#  (u'restaurant', 2),
#  (u'roof', 2),
#  (u'roundabout', 2),
#  (u'sandpit', 2),
#  (u'seesaw', 2),
#  (u'short', 2),
#  (u'signal:crossing_distant:deactivated', 2),
#  (u'sk', 2),
#  (u'slide', 2),
#  (u'snack', 2),
#  (u'springy', 2),
#  (u'sq', 2),
#  (u'sr', 2),
#  (u'ssid', 2),
#  (u'station:part', 2),
#  (u'steps', 2),
#  (u'swing', 2),
#  (u'switch:configuration', 2),
#  (u'taxon', 2),
#  (u'teenshelter', 2),
#  (u'tenant', 2),
#  (u'trampoline', 2),
#  (u'tree_house', 2),
#  (u'tunnel', 2),
#  (u'tunnel_tube', 2),
#  (u'twitter', 2),
#  (u'type2_combo', 2),
#  (u'underground_cable', 2),
#  (u'vanes', 2),
#  (u'vehicle_inspection', 2),
#  (u'ventilation', 2),
#  (u'water', 2),
#  (u'water_level', 2),
#  (u'western', 2),
#  (u'wlan', 2),
#  (u'youtube', 2),
#  (u'zh-Hans', 2),
#  (u'zh-Hant', 2),
#  (u'zipwire', 2),
#  (u'3dr_dormer', 1),
#  (u'3dr_type', 1),
#  (u'Bearing', 1),
#  (u'EEG', 1),
#  (u'Geek_Quotient', 1),
#  (u'ISO3166-2', 1),
#  (u'LH2', 1),
#  (u'Note', 1),
#  (u'Website', 1),
#  (u'af', 1),
#  (u'after_school', 1),
#  (u'airmark', 1),
#  (u'als', 1),
#  (u'alteration_serive', 1),
#  (u'alteration_service', 1),
#  (u'altl_name', 1),
#  (u'amenity_1', 1),
#  (u'amount', 1),
#  (u'an', 1),
#  (u'animal', 1),
#  (u'apartment', 1),
#  (u'ar', 1),
#  (u'arc', 1),
#  (u'art', 1),
#  (u'ata', 1),
#  (u'authentication', 1),
#  (u'auto_update', 1),
#  (u'az', 1),
#  (u'backward', 1),
#  (u'bag', 1),
#  (u'balance_beam', 1),
#  (u'balancebeam', 1),
#  (u'bancomat', 1),
#  (u'barrier_free_lines', 1),
#  (u'beachclub', 1),
#  (u'beacon_lateral:system', 1),
#  (u'beacon_special_purpose:colour', 1),
#  (u'beacon_special_purpose:shape', 1),
#  (u'beauty_nails', 1),
#  (u'beavers', 1),
#  (u'beer', 1),
#  (u'bettundbike', 1),
#  (u'beverage_cartons', 1),
#  (u'bg', 1),
#  (u'bic', 1),
#  (u'bicycle:diy', 1),
#  (u'bicycles', 1),
#  (u'billards', 1),
#  (u'biometric', 1),
#  (u'birth', 1),
#  (u'bn', 1),
#  (u'br', 1),
#  (u'braille:de', 1),
#  (u'bridge:clearance_width', 1),
#  (u'bs', 1),
#  (u'building:function', 1),
#  (u'buildingpart', 1),
#  (u'bunker_type', 1),
#  (u'buoy_cardinal:category', 1),
#  (u'buoy_cardinal:colour', 1),
#  (u'buoy_cardinal:colour_pattern', 1),
#  (u'buse', 1),
#  (u'business', 1),
#  (u'ca', 1),
#  (u'calling-in_point:callsign', 1),
#  (u'capacity_smoker_free', 1),
#  (u'capital', 1),
#  (u'car_repair', 1),
#  (u'cds', 1),
#  (u'charging', 1),
#  (u'chemical_toilet', 1),
#  (u'cigarettes', 1),
#  (u'closed', 1),
#  (u'code', 1),
#  (u'collector', 1),
#  (u'combination_of_public_administration', 1),
#  (u'combo2', 1),
#  (u'comics', 1),
#  (u'community', 1),
#  (u'company', 1),
#  (u'compressed_air', 1),
#  (u'concentration_camp', 1),
#  (u'conflict', 1),
#  (u'continent', 1),
#  (u'copier', 1),
#  (u'copy', 1),
#  (u'copyshop', 1),
#  (u'cork', 1),
#  (u'county', 1),
#  (u'cy', 1),
#  (u'da', 1),
#  (u'date_off', 1),
#  (u'date_on', 1),
#  (u'description:en', 1),
#  (u'destination', 1),
#  (u'destination:housenumber', 1),
#  (u'destination:type', 1),
#  (u'dhlpaketshop', 1),
#  (u'diners_club', 1),
#  (u'direction_east', 1),
#  (u'direction_northeast', 1),
#  (u'direction_southeast', 1),
#  (u'direction_southwest', 1),
#  (u'disabled_spaces', 1),
#  (u'doctors', 1),
#  (u'drink', 1),
#  (u'dsb', 1),
#  (u'ec', 1),
#  (u'education_profile', 1),
#  (u'el', 1),
#  (u'elevator_machineid', 1),
#  (u'elevator_operatorid', 1),
#  (u'emergency_service', 1),
#  (u'emergency_ward_entrance', 1),
#  (u'enforcement_method', 1),
#  (u'enforcement_period', 1),
#  (u'enforcement_type', 1),
#  (u'entrance_1', 1),
#  (u'et', 1),
#  (u'eu', 1),
#  (u'euroshell', 1),
#  (u'exit', 1),
#  (u'facility', 1),
#  (u'family', 1),
#  (u'fastfood', 1),
#  (u'fence_type', 1),
#  (u'fi', 1),
#  (u'field', 1),
#  (u'fish', 1),
#  (u'flagpole', 1),
#  (u'fluorescent_tubes', 1),
#  (u'ford', 1),
#  (u'frontcooking', 1),
#  (u'fuel:lpg', 1),
#  (u'full', 1),
#  (u'fur', 1),
#  (u'fy', 1),
#  (u'ga', 1),
#  (u'gangbang', 1),
#  (u'gauge:n', 1),
#  (u'gd', 1),
#  (u'geldkarte', 1),
#  (u'gender', 1),
#  (u'gl', 1),
#  (u'golf', 1),
#  (u'gravity', 1),
#  (u'green_glass', 1),
#  (u'grey_water', 1),
#  (u'he', 1),
#  (u'hermes_shop', 1),
#  (u'high', 1),
#  (u'hinge', 1),
#  (u'hint', 1),
#  (u'honorary', 1),
#  (u'hotelstars', 1),
#  (u'housenumber_1', 1),
#  (u'houseware', 1),
#  ...]

# %% [markdown]
# ### Looking for 'restaurants' in the database

# %%
dbUdacity.query_AllResults('''SELECT nodes_tags.value
                                    , count (nodes_tags.key) as Sum    
                                FROM nodes_tags                                    
                                WHERE nodes_tags.key = "restaurant"                                    
                                GROUP BY nodes_tags.value
                                ORDER BY Sum DESC
                            ;''')
# Out:
# [(u'cafe', 1), (u'yes', 1)]

# %%
dbUdacity.query_AllResults('''SELECT nodes_tags.value
                                    , count (nodes_tags.key) as Sum    
                                FROM nodes_tags                                    
                                WHERE nodes_tags.key = "amenity"                                    
                                GROUP BY nodes_tags.value
                                ORDER BY Sum DESC
                            ;''')
# Out:
# [(u'bench', 2531),
#  (u'restaurant', 1527),
#  (u'post_box', 1015),
#  (u'vending_machine', 838),
#  (u'recycling', 834),
#  (u'parking', 763),
#  (u'cafe', 669),
#  (u'fast_food', 638),
#  (u'waste_basket', 463),
#  (u'bicycle_parking', 462),
#  (u'telephone', 410),
#  (u'pub', 383),
#  (u'doctors', 361),
#  (u'pharmacy', 328),
#  (u'bank', 289),
#  (u'kindergarten', 244),
#  (u'clock', 198),
#  (u'toilets', 198),
#  (u'bar', 192),
#  (u'bicycle_rental', 190),
#  (u'parking_entrance', 184),
#  (u'atm', 152),
#  (u'post_office', 149),
#  (u'library', 146),
#  (u'taxi', 119),
#  (u'fuel', 114),
#  (u'dentist', 107),
#  (u'charging_station', 103),
#  (u'place_of_worship', 76),
#  (u'social_facility', 76),
#  (u'shelter', 71),
#  (u'driving_school', 64),
#  (u'school', 62),
#  (u'fountain', 60),
#  (u'community_centre', 53),
#  (u'car_rental', 52),
#  (u'theatre', 52),
#  (u'ice_cream', 49),
#  (u'car_sharing', 44),
#  (u'waste_disposal', 44),
#  (u'motorcycle_parking', 43),
#  (u'fire_station', 41),
#  (u'veterinary', 41),
#  (u'nightclub', 39),
#  (u'embassy', 35),
#  (u'cinema', 26),
#  (u'car_wash', 25),
#  (u'drinking_water', 25),
#  (u'gambling', 23),
#  (u'marketplace', 23),
#  (u'police', 23),
#  (u'ferry_terminal', 20),
#  (u'university', 20),
#  (u'arts_centre', 17),
#  (u'grit_bin', 14),
#  (u'studio', 14),
#  (u'bbq', 13),
#  (u'boat_rental', 13),
#  (u'parking_space', 12),
#  (u'advertising', 11),
#  (u'casino', 11),
#  (u'life_ring', 11),
#  (u'public_building', 11),
#  (u'compressed_air', 10),
#  (u'photo_booth', 10),
#  (u'swingerclub', 10),
#  (u'biergarten', 9),
#  (u'brothel', 8),
#  (u'college', 8),
#  (u'smoking_area', 8),
#  (u'bureau_de_change', 7),
#  (u'hunting_stand', 7),
#  (u'bus_station', 6),
#  (u'dancing_school', 6),
#  (u'hospital', 6),
#  (u'internet_cafe', 6),
#  (u'childcare', 5),
#  (u'education', 5),
#  (u'obstacle', 5),
#  (u'office', 5),
#  (u'townhall', 5),
#  (u'building_entrance', 4),
#  (u'music_venue', 4),
#  (u'nursing_home', 4),
#  (u'baby_hatch', 3),
#  (u'canteen', 3),
#  (u'customs', 3),
#  (u'dojo', 3),
#  (u'fireplace', 3),
#  (u'food_court', 3),
#  (u'cooking_school', 2),
#  (u'coworking_space', 2),
#  (u'government', 2),
#  (u'grave_yard', 2),
#  (u'library_station', 2),
#  (u'nursing_service', 2),
#  (u'planed', 2),
#  (u'pneumatic_tube_transport', 2),
#  (u'public_bookcase', 2),
#  (u'sanitary_dump_station', 2),
#  (u'shower', 2),
#  (u'trolley_bay', 2),
#  (u'vacant', 2),
#  (u'Dentallabor', 1),
#  (u'Rechtsanw\xe4lte', 1),
#  (u'adult_cinema', 1),
#  (u'architektursommer', 1),
#  (u'bakery', 1),
#  (u'beauty_salon', 1),
#  (u'bicycle_repair_station', 1),
#  (u'bin', 1),
#  (u'boat_sharing', 1),
#  (u'cafeteria', 1),
#  (u'charity', 1),
#  (u'clinic', 1),
#  (u'community_centre:for', 1),
#  (u'courthouse', 1),
#  (u'crematorium', 1),
#  (u'depot', 1),
#  (u'elevator', 1),
#  (u'events_venue', 1),
#  (u'fire_brigade_entrance', 1),
#  (u'funeral_home', 1),
#  (u'gallery', 1),
#  (u'healthcare', 1),
#  (u'ice_cream;cafe', 1),
#  (u'kiosk', 1),
#  (u'language_school', 1),
#  (u'music_school', 1),
#  (u'nursery', 1),
#  (u'post_box_inoperable', 1),
#  (u'preschool', 1),
#  (u'prison', 1),
#  (u'prison_camp', 1),
#  (u'pub;restaurant', 1),
#  (u'publishing_house', 1),
#  (u'rescue_service', 1),
#  (u'retirement_home', 1),
#  (u'sauna', 1),
#  (u'scout_hut', 1),
#  (u'self_storage', 1),
#  (u'social_centre', 1),
#  (u'speed_trap', 1),
#  (u'stripclub', 1),
#  (u'survey', 1),
#  (u'vehicle_inspection', 1),
#  (u'watch', 1),
#  (u'water_point', 1),
#  (u'wlan', 1)]

# %% [markdown]
# ### Looking for 'religion' in the database

# %%
dbUdacity.query_AllResults('''SELECT nodes_tags.value
                                    , count (nodes_tags.key) as Sum    
                                FROM nodes_tags                                    
                                WHERE nodes_tags.key = "religion"                                    
                                GROUP BY nodes_tags.value
                                ORDER BY Sum DESC
                            ;''')
# Out:
# [(u'christian', 51),
#  (u'muslim', 23),
#  (u'all', 1),
#  (u'buddhist', 1),
#  (u'hindu', 1),
#  (u'scientologist', 1),
#  (u'sikh', 1)]

# %%
dbUdacity.query_AllResults('''SELECT nodes_tags.value
                                    , count (nodes_tags.key) as Sum    
                                FROM nodes_tags                                    
                                WHERE nodes_tags.key = "religion"                                    
                                GROUP BY nodes_tags.value
                                ORDER BY Sum DESC
                            ;''')
# Out:
# [(u'christian', 51),
#  (u'muslim', 23),
#  (u'all', 1),
#  (u'buddhist', 1),
#  (u'hindu', 1),
#  (u'scientologist', 1),
#  (u'sikh', 1)]

# %% [markdown]
# <a id="3"></a>
# # Conclusion
# ***
# The OpenStreetMap data of Hamburg, Germany is of fairly reasonable quality. The overall level of systematically completeness very low, e.g. if total numbers of rows for streets are compared to total numbers of rows for postcodes, phone numbers, amenity, restaurant or any other meaningful piece of information.
#
# Furthermore, the type of information requested for a given location is not systematically required during input leading to disadvantages to competitors like GoogleMaps.
#
# In the detailed analysis, the input typos of humans for street names are so rare, that obviously some sort of data cleaning has been already occured. Same for Postal (ZIP) Codes, because there are all of correct digits. The only big issue remains about standardized format for phone numbers.
#
# Although Open Source Community has undertaken a very high level of effort, to provide a very good free map, there are still a lot of gaps compared to competitors like GoogleMaps, e.g.
#
# * indicated public transportation stops & their lines,
# * traffic jams,
# * touristic attractions,
# * company location - including direct hyperlink to homesite etc.
#
# ## Additional suggestions & Ideas
#
# * __General level of available Information__
#
#     In general, the available type of information is reasonble non-systematic and seems to depend purely on user
#     interest.
#
#     For example, if 'nodes_tags'.key = 'amenity', there are 1527 'nodes_tags'.values = 'restaurants' listed. However,
#     there is listed as 'nodes_tags'.key = 'restaurant' listed additional further 2 ones. as  keyCompared to other regions in the world, there are absolutely no information given by any of these tags:
#     - *'restaurant'* (only 2 rows)
#     - *'religion'* (79 rows)
#
#
# * __typos and well-formatted input__
#
#     Typically, post-entering cleaning activities should be avoided as there are easy to implement prevention measures,
#     e.g. GUI / CSS format patterns
#
#     Usually, directly at input prompting, there needs to be a formatting validation, to cross-check if entered patterns
#     are meeting defined format. Therefore, it is necessary only to determine an associated css-classin html5 and a
#     stored pattern in the database.
#
#     This prevents any user to indicate undesired input. Only validated, well-formatted information will be stored in
#     database in the background.
#
#
# * __Marketshare__
#
#     Similar to Google, OpenStreetMap should set-up an agreement with manufacturers of mobile devices for pre-loading
#     OpenStreetMap and encouraging users to provide systematically more information to pre-defined areas of interest.
#     In order not to "overload" users with request, there should be defined first a roll-out concept, which type of
#     information first should be requested first.

# %% [markdown]
# <a id="4"></a>
# # Bibliography & Files
# ***
#
# - OSM files
#     - OpenStreetMap-Hamburg-31.osm
#     - OpenStreetMap-Hamburg-Sample.osm
#
#
# - Python classes & methods
#     - class myXML.py
#     - class mySQL3dbConn.py
#     - module myExtension.py, containing class 'myUnicodeDictWriter' inherited from csv.DictWriter and
#       class 'myDict2CSVTransformer'
#     - module schema.py
#     - __[Sphinx Documentation jfo package](./doc/modules.html)__
#
#
# - csv files
#     - nodes.csv
#     - nodes_tags.csv
#     - ways.csv
#     - ways_nodes.csv
#     - ways_tags.csv
#
#
# - SQL files
#     - OSM_Create_Tables.sql
#     - OSM_Drop_Tables.sql
#     - OSM_Import_CSV.sql
#
#
# - osmHamburg.db SQL3Lite database
#
#
# - Readme.md
